# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import log_loss
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Churn_Modelling.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data = data.drop(columns=["RowNumber","CustomerId","Surname"])
data.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
data = data.drop(columns=['Geography','Gender'])
data.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1
# 3               0         93826.63       0
# 4               1         79084.10       0

# %% [markdown]
# # scaling data

# %%
x= data.drop('Exited', axis=1).values
y= data.iloc[:,-1].values.reshape(-1,1)
scalar= MinMaxScaler()
x= scalar.fit_transform(x)
y=scalar.fit_transform(y)

# %% [markdown]
# # split data && oversampling

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2024)


ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)

# %%
model = Sequential()
model.add(Dense(11, input_dim=8, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))


model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_resampled, y_resampled, epochs=50, batch_size=1)


loss, accuracy = model.evaluate(X_resampled, y_resampled)
print("Loss:", loss)
print("Accuracy:", accuracy)


predictions = model.predict(X_test)
bce = log_loss(y_test, predictions)
print("Binary Cross-Entropy Error:", bce)
# Out:
# Epoch 1/50
# 11156/11156 [==============================] - 42s 4ms/step - loss: 0.5841 - accuracy: 0.6736
# Epoch 2/50
# 11156/11156 [==============================] - 39s 3ms/step - loss: 0.5109 - accuracy: 0.7340
# Epoch 3/50
# 11156/11156 [==============================] - 39s 3ms/step - loss: 0.4985 - accuracy: 0.7451
# Epoch 4/50
# 11156/11156 [==============================] - 43s 4ms/step - loss: 0.4930 - accuracy: 0.7465
# Epoch 5/50
# 11156/11156 [==============================] - 42s 4ms/step - loss: 0.4895 - accuracy: 0.7445
# Epoch 6/50
# 11156/11156 [==============================] - 37s 3ms/step - loss: 0.4861 - accuracy: 0.7463
# Epoch 7/50
# 11156/11156 [==============================] - 36s 3ms/step - loss: 0.4832 - accuracy: 0.7526
# Epoch 8/50
# 11156/11156 [==============================] - 38s 3ms/step - loss: 0.4815 - accuracy: 0.7550
# Epoch 9/50
# 11156/11156 [==============================] - 34s 3ms/step - loss: 0.4808 - accuracy: 0.7539
# Epoch 10/50
# 11156/11156 [==============================] - 32s 3ms/step - loss: 0.4778 - accuracy: 0.7516
# Epoch 11/50
# 11156/11156 [==============================] - 35s 3ms/step - loss: 0.4756 - accuracy: 0.7548
# Epoch 12/50
# 11156/11156 [==============================] - 34s 3ms/step - loss: 0.4731 - accuracy: 0.7574
# Epoch 13/50
# 11156/11156 [==============================] - 34s 3ms/step - loss: 0.4698 - accuracy: 0.7643
# Epoch 14/50
# 11156/11156 [==============================] - 29s 3ms/step - loss: 0.4680 - accuracy: 0.7590
# Epoch 15/50
# 11156/11156 [==============================] - 30s 3ms/step - loss: 0.4673 - accuracy: 0.7634
# Epoch 16/50
# 11156/11156 [==============================] - 30s 3ms/step - loss: 0.4675 - accuracy: 0.7614
# Epoch 17/50
# 11156/11156 [==============================] - 29s 3ms/step - loss: 0.4651 - accuracy: 0.7631
# Epoch 18/50
# 11156/11156 [==============================] - 30s 3ms/step - loss: 0.4651 - accuracy: 0.7641
# Epoch 19/50
# 11156/11156 [==============================] - 27s 2ms/step - loss: 0.4645 - accuracy: 0.7636
# Epoch 20/50
# 11156/11156 [==============================] - 31s 3ms/step - loss: 0.4638 - accuracy: 0.7627
# Epoch 21/50
# 11156/11156 [==============================] - 27s 2ms/step - loss: 0.4604 - accuracy: 0.7667
# Epoch 22/50
# 11156/11156 [==============================] - 29s 3ms/step - loss: 0.4590 - accuracy: 0.7668
# Epoch 23/50
# 11156/11156 [==============================] - 29s 3ms/step - loss: 0.4593 - accuracy: 0.7682
# Epoch 24/50
# 11156/11156 [==============================] - 28s 3ms/step - loss: 0.4605 - accuracy: 0.7667
# Epoch 25/50
# 11156/11156 [==============================] - 27s 2ms/step - loss: 0.4569 - accuracy: 0.7703
# Epoch 26/50
# 11156/11156 [==============================] - 27s 2ms/step - loss: 0.4569 - accuracy: 0.7659
# Epoch 27/50
# 11156/11156 [==============================] - 27s 2ms/step - loss: 0.4559 - accuracy: 0.7686
# Epoch 28/50
# 11156/11156 [==============================] - 28s 2ms/step - loss: 0.4559 - accuracy: 0.7683
# Epoch 29/50
# 11156/11156 [==============================] - 26s 2ms/step - loss: 0.4546 - accuracy: 0.7692
# Epoch 30/50
# 11156/11156 [==============================] - 25s 2ms/step - loss: 0.4548 - accuracy: 0.7690
# Epoch 31/50
# 11156/11156 [==============================] - 28s 3ms/step - loss: 0.4542 - accuracy: 0.7690
# Epoch 32/50
# 11156/11156 [==============================] - 29s 3ms/step - loss: 0.4540 - accuracy: 0.7698
# Epoch 33/50
# 11156/11156 [==============================] - 27s 2ms/step - loss: 0.4530 - accuracy: 0.7694
# Epoch 34/50
# 11156/11156 [==============================] - 27s 2ms/step - loss: 0.4515 - accuracy: 0.7692
# Epoch 35/50
# 11156/11156 [==============================] - 27s 2ms/step - loss: 0.4517 - accuracy: 0.7680
# Epoch 36/50
# 11156/11156 [==============================] - 25s 2ms/step - loss: 0.4519 - accuracy: 0.7695
# Epoch 37/50
# 11156/11156 [==============================] - 24s 2ms/step - loss: 0.4526 - accuracy: 0.7687
# Epoch 38/50
# 11156/11156 [==============================] - 25s 2ms/step - loss: 0.4513 - accuracy: 0.7689
# Epoch 39/50
# 11156/11156 [==============================] - 25s 2ms/step - loss: 0.4498 - accuracy: 0.7718
# Epoch 40/50
# 11156/11156 [==============================] - 25s 2ms/step - loss: 0.4499 - accuracy: 0.7701
# Epoch 41/50
# 11156/11156 [==============================] - 25s 2ms/step - loss: 0.4505 - accuracy: 0.7686
# Epoch 42/50
# 11156/11156 [==============================] - 28s 2ms/step - loss: 0.4487 - accuracy: 0.7703
# Epoch 43/50
# 11156/11156 [==============================] - 24s 2ms/step - loss: 0.4503 - accuracy: 0.7669
# Epoch 44/50
# 11156/11156 [==============================] - 28s 3ms/step - loss: 0.4512 - accuracy: 0.7661
# Epoch 45/50
# 11156/11156 [==============================] - 31s 3ms/step - loss: 0.4493 - accuracy: 0.7660
# Epoch 46/50
# 11156/11156 [==============================] - 29s 3ms/step - loss: 0.4518 - accuracy: 0.7661
# Epoch 47/50
# 11156/11156 [==============================] - 26s 2ms/step - loss: 0.4523 - accuracy: 0.7685
# Epoch 48/50
# 11156/11156 [==============================] - 25s 2ms/step - loss: 0.4476 - accuracy: 0.7685
# Epoch 49/50
# 11156/11156 [==============================] - 30s 3ms/step - loss: 0.4457 - accuracy: 0.7707
# Epoch 50/50
# 11156/11156 [==============================] - 30s 3ms/step - loss: 0.4465 - accuracy: 0.7701
# 349/349 [==============================] - 1s 2ms/step - loss: 0.4395 - accuracy: 0.7718
# Loss: 0.43950265645980835
# Accuracy: 0.7717819809913635
# 94/94 [==============================] - 0s 1ms/step
# Binary Cross-Entropy Error: 0.47318272052795557
